# %%
import torch
from torch import optim
from deki import Rosenbrock, Sphere

# %%
opt_config = (optim.Adam, {"lr":2.5E-1})
Rosenbrock.plot(opt_config, steps=1000, save=False)

# %%
Sphere.plot(opt_config, steps=1000, save=False)
