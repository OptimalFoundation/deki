# %%
import torch
from torch import optim
from deki import Rosenbrock, BohachevskyN3, BohachevskyN2, BohachevskyN1

# %%
opt_config = (optim.Adam, {"lr":2.5E-1})
BohachevskyN1.plot(opt_config, steps=1000, save=False)

# %%
Rosenbrock.plot(opt_config, steps=1000, save=False)
